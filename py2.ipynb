# %% [markdown]
# <a href="https://colab.research.google.com/github/Adithya-pkl/google-colab/blob/master/py2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from google.colab import files
uploaded=files.upload

# %%
#example program on images using MNIST dataset
import matplotlib.pyplot as plt
from tensorflow import keras

#load MNIST dataset (predefined)
(x_train, y_train),(x_test,y_test)=keras.datasets.mnist.load_data()

#display functions for images
def show_images(images,labels, num=10):
    plt.figure(figsize=(10,5))
    for i in range(num):
      plt.subplot(2, 5, i+1) #print 10 images in 2 different lines
      plt.imshow(images[i], cmap='gray')
      plt.title(f"label :{labels[i]}")
      plt.axis('off')
      plt.show()
show_images(x_train, y_train)

# %%
#importing libraries
import torch
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt

#load an image into IDE
image_path="/content/download.jpeg"

image=Image.open(image_path)

#define transformation
transform=transforms.Compose([
  transforms.Resize((128,128)),
  transforms.ToTensor(), #Convert to tensor

])

#Apply transformation
image_tensor=transform(image)

#Convert tensor back to image for display as an output
image_numpy=image_tensor.permute(1,2,0).numpy()

#display the image
plt.imshow(image_numpy)
plt.axis('off')
plt.title("transformed images")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-05229adf-7f37-4228-a28f-3888ac979a53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05229adf-7f37-4228-a28f-3888ac979a53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("crop_yield_data.xls")  # Replace with the actual file name
print(df.head())  # Display the first few rows
X = df.drop('crop_yield', axis=1)
y = df['crop_yield']
# Out:
#    temperature  humidity  rainfall  soil_quality  fertilizer_used  crop_yield
# 0           25        60        50             7              200        2000
# 1           28        65        60             6              220        2200
# 2           24        58        40             8              180        1800
# 3           26        62        55             7              210        2100
# 4           22        59        45             6              190        1900

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))  # For regression output
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 4505874.0000
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 4505770.0000
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 4505671.5000
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 4505576.0000
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 4505481.5000
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 4505386.5000
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 4505291.5000
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 4505197.5000
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 4505104.0000
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 4505010.0000
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 4504915.0000
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 4504819.0000
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 4504721.5000
# Epoch 14/100
# ...

# %%
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 5231551.5000
# Test Loss: 5231551.5
